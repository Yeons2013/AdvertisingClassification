# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from urllib.parse import quote_plus
from urllib.parse import unquote_plus

# %%
from blog import blog_restaurants

# %%
food = blog_restaurants()
# Out:
# 지역을 입력해주세요 : 서울 성수동

# %%
# 키워드에 해당하는 지역 맛집 게시글 크롤링
food.blog_restaurant_get()

# %%
# 가져오 게시글에 해당하는 식당명 크롤링
food.naver_restaurants_get()

# %%
# 글이 많이 게시된 식당 10개 선별
food.top_10_restaurant_get()

# %%
# 10개의 식당에 대한 글 크롤링 후 저장
food.restaurant_get()
